# %%
import nashpy as nash
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt

# %%
for K in [1,2,3,5,10]:
    N=20
    C=0
    gamma=1.0
    p=1.
    s1= math.exp(1)**gamma/(math.exp(1)**gamma +  p*math.exp(0)**gamma)
    s2= math.exp(1)**gamma/(math.exp(1)**gamma +  math.exp(0)**gamma)
    a=0.5
    a1=1.0
    #K=1
    u11= N/(K+1)**2 *a + s1* N/K**2 *a1 -C/(K+1)
    u12= s2*N/(K+1)**2 *a +N/K**2 *a1   -C/(K+1)
    u13= N/(K+1)**2 *a + N/K**2 *a1      -C/(K+1)

    u21= N/(K+2)**2 *a + s1*N/K**2 *a1-C/(K+2)
    u22= N/(K+2)**2 *a + N/K**2 *a1-C/(K+2)
    u23= s2* N/(K+2)**2 *a + N/K**2 *a1-C/(K+2)

    l11= (1-s1)*N/K**2 *a1 -C/K
    l12= (1-s2)*N/(K+1)**2 *a-C/(K+1)
    l13= N/(K+2)**2 *a -C/(K+2)

    l21= (1-s1)* N/K**2 *a1-C/K
    l22= N/(K+1)**2 *a-C/(K+1)
    l23= (1-s2)*N/(K+2)**2 *a-C/(K+2)

    A= np.array([[u11,u12,u13],[u21,u22,u23]])
    B= np.array([[l11,l12,l13],[l21,l22,l23]])
    game = nash.Game(A, B)
    eqs=game.support_enumeration()
    print(K,list(eqs))
# Out:
# 1 [(array([1., 0.]), array([1., 0., 0.]))]
# 2 [(array([1., 0.]), array([1., 0., 0.]))]
# 3 [(array([1., 0.]), array([1., 0., 0.]))]
# 5 [(array([1., 0.]), array([1., 0., 0.])), (array([0., 1.]), array([0., 1., 0.])), (array([0.30838665, 0.69161335]), array([0.01351707, 0.98648293, 0.        ]))]
# 10 [(array([1., 0.]), array([0., 0., 1.])), (array([0., 1.]), array([0., 1., 0.])), (array([0.47761119, 0.52238881]), array([0.40610776, 0.59389224, 0.        ]))]

# %%
    game = nash.Game(A, B)
    eqs=game.support_enumeration()
# Out:
# []

# %%
for K in [1,2,3,5,10]:
    N=20
    C=0
    gamma=2
    p=1
    s1= math.exp(1)**gamma/(math.exp(1)**gamma +  p*math.exp(0)**gamma)
    s2= math.exp(1)**gamma/(math.exp(1)**gamma +  math.exp(0)**gamma)
    a=0.5
    a1=0.1
 
    u11= N/(K+1) *a + s1* N/K *a1 -C/(K+1)
    u12= s2*N/(K+1) *a +N/K *a1   -C/(K+1)
    u13= N/(K+1) *a + N/K *a1      -C/(K+1)

    u21= N/(K+2) *a + s1*N/K *a1-C/(K+2)
    u22= N/(K+2) *a + N/K *a1-C/(K+2)
    u23= s2* N/(K+2) *a + N/K *a1-C/(K+2)

    l11= (1-s1)*N/K *a1 -C/K
    l12= (1-s2)*N/(K+1) *a-C/(K+1)
    l13= N/(K+2) *a -C/(K+2)

    l21= (1-s1)* N/K *a1-C/K
    l22= N/(K+1) *a-C/(K+1)
    l23= (1-s2)*N/(K+2) *a-C/(K+2)

    A= np.array([[u11,u12,u13],[u21,u22,u23]])
    B= np.array([[l11,l12,l13],[l21,l22,l23]])
    game = nash.Game(A, B)
    eqs=game.support_enumeration()
    eqs=list(eqs)
    #print (round(u11,4),round(l11,4), " | ", round(u12,4),round(l12,4), " | ", round(u13,4),round(l13,4), " | ")
    #print ("                                             ")
    #print (round(u21,4),round(l21,4), " | ", round(u22,4),round(l22,4), " | ", round(u23,4),round(l23,4), " | ")
    print(K,len(eqs),eqs)
# Out:
# 1 1 [(array([1., 0.]), array([0., 0., 1.]))]
# 2 1 [(array([1., 0.]), array([0., 0., 1.]))]
# 3 1 [(array([1., 0.]), array([0., 0., 1.]))]
# 5 1 [(array([1., 0.]), array([0., 0., 1.]))]
# 10 3 [(array([1., 0.]), array([0., 0., 1.])), (array([0., 1.]), array([0., 1., 0.])), (array([0.52762327, 0.47237673]), array([0.        , 0.84300244, 0.15699756]))]

# %%
for a1 in np.arange(0,1.1,0.1):  
    a=0.5
    C=0
    N=20
    p=1
    x1=[]
    x2=[]
    x3=[]
    x4=[]
    x5=[]
  

    y1=[]
    y2=[]
    y3=[]
    y4=[]
    y5=[]
    gamma_list=np.arange(0,5,0.1)
    K_list=np.arange(1.,51.,1)

    x=[]
    y=[]
    for gamma in gamma_list:
        for K in K_list:
            x.append(gamma)
            y.append(K)
    for gamma,K in zip(x,y):
        s1= math.exp(1)**gamma/(math.exp(1)**gamma +  p*math.exp(0)**gamma)
        s2= math.exp(1)**gamma/(math.exp(1)**gamma +  math.exp(0)**gamma)

        u11= N/(K+1)**2 *a + s1* N/K**2 *a1 -C/(K+1)
        u12= s2*N/(K+1)**2 *a +N/K**2 *a1   -C/(K+1)
        u13= N/(K+1)**2 *a + N/K**2 *a1      -C/(K+1)

        u21= N/(K+2)**2 *a + s1*N/K**2 *a1-C/(K+2)
        u22= N/(K+2)**2 *a + N/K**2 *a1-C/(K+2)
        u23= s2* N/(K+2)**2 *a + N/K**2 *a1-C/(K+2)

        l11= (1-s1)*N/K**2 *a1 -C/K
        l12= (1-s2)*N/(K+1)**2 *a-C/(K+1)
        l13= N/(K+2)**2 *a -C/(K+2)

        l21= (1-s1)* N/K**2 *a1-C/K
        l22= N/(K+1)**2 *a-C/(K+1)
        l23= (1-s2)*N/(K+2)**2 *a-C/(K+2)

        A= np.array([[u11,u12,u13],[u21,u22,u23]])
        B= np.array([[l11,l12,l13],[l21,l22,l23]])
        game = nash.Game(A, B)
        eqs=game.support_enumeration()
        eqs=list(eqs)

        if len(eqs)==1:
            if [1,0]==eqs[0][0].tolist() and [0,1,0]==eqs[0][1].tolist():
                x1.append(gamma)
                y1.append(K)
            if [1,0]==eqs[0][0].tolist() and [1,0,0]==eqs[0][1].tolist():
                x2.append(gamma)
                y2.append(K)
            if [1,0]==eqs[0][0].tolist() and [0,0,1]==eqs[0][1].tolist():
                x3.append(gamma)
                y3.append(K)

        if len(eqs)>1:
            if [1,0]==eqs[0][0].tolist() and [1,0,0]==equs[0][1].tolist():
                x4.append(gamma)
                y4.append(K)
            else:
                x5.append(gamma)
                y5.append(K)
   
    #plt.style.use('classic')
    plt.figure(figsize=(9,6))
    plt.axis([0, 51, -0.1, 5.])
    #,color="black")
    
    plt.plot(y2,x2,"o",label="(K+1,K)")#,color="red")
    plt.plot(y1,x1,"o",label="(K+1,K+1)")
    plt.plot(y3,x3,"o",label="(K+1,K+2)")#,color="grey")
    plt.plot(y4,x4,"o",label="(K+1,K+2),(K+2,K+1)")
    plt.xlabel('K',fontsize=18)
    plt.ylabel(r'$\gamma$',fontsize=18)
    title=r"$p=1$  $E(\alpha) = 0.5$" + "  " + r"$ \alpha_K=" +str(round(a1,1)) +"$"
    plt.legend(loc='upper left',framealpha=1)
    plt.title(title,fontsize=20)
    name="p_1.0_alpha_k_"+str(round(a1,1)) +".png"
    plt.savefig(name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-8f93bc33e9f0> in <module>()
#      63
#      64         if len(eqs)>1:
# ---> 65             if [1,0]==eqs[0][0].tolist() and [1,0,0]==equs[0][1].tolist():
#      66                 x4.append(gamma)
#      67                 y4.append(K)
#
# NameError: name 'equs' is not defined

# %%
def static_two(a1):
    a=0.5
    C=0
    N=20
    p=1
    
    x1=[]
    x2=[]
    x3=[]
    x4=[]
    x5=[]
  

    y1=[]
    y2=[]
    y3=[]
    y4=[]
    y5=[]
    gamma_list=np.arange(0,5,0.1)
    K_list=np.arange(1.,51.,1)

    x=[]
    y=[]
    for gamma in gamma_list:
        for K in K_list:
            x.append(gamma)
            y.append(K)
    for gamma,K in zip(x,y):
        s1= math.exp(1)**gamma/(math.exp(1)**gamma +  p*math.exp(0)**gamma)
        s2= math.exp(1)**gamma/(math.exp(1)**gamma +  math.exp(0)**gamma)

        u11= N/(K+1)**2 *a + s1* N/K**2 *a1 -C/(K+1)
        u12= s2*N/(K+1)**2 *a +N/K**2 *a1   -C/(K+1)
        u13= N/(K+1)**2 *a + N/K**2 *a1      -C/(K+1)

        u21= N/(K+2)**2 *a + s1*N/K**2 *a1-C/(K+2)
        u22= N/(K+2)**2 *a + N/K**2 *a1-C/(K+2)
        u23= s2* N/(K+2)**2 *a + N/K**2 *a1-C/(K+2)

        l11= (1-s1)*N/K**2 *a1 -C/K
        l12= (1-s2)*N/(K+1)**2 *a-C/(K+1)
        l13= N/(K+2)**2 *a -C/(K+2)

        l21= (1-s1)* N/K**2 *a1-C/K
        l22= N/(K+1)**2 *a-C/(K+1)
        l23= (1-s2)*N/(K+2)**2 *a-C/(K+2)

        A= np.array([[u11,u12,u13],[u21,u22,u23]])
        B= np.array([[l11,l12,l13],[l21,l22,l23]])
        game = nash.Game(A, B)
        eqs=game.support_enumeration()
        eqs=list(eqs)

        if len(eqs)==1:
            if [1,0]==eqs[0][0].tolist() and [0,1,0]==eqs[0][1].tolist():
                x1.append(gamma)
                y1.append(K)
            if [1,0]==eqs[0][0].tolist() and [1,0,0]==eqs[0][1].tolist():
                x2.append(gamma)
                y2.append(K)
            if [1,0]==eqs[0][0].tolist() and [0,0,1]==eqs[0][1].tolist():
                x3.append(gamma)
                y3.append(K)

        if len(eqs)>1:
            if [1,0]==eqs[0][0].tolist() and [1,0,0]==eqs[0][1].tolist():
                x4.append(gamma)
                y4.append(K)
            else:
                x5.append(gamma)
                y5.append(K)
            
    return x1,x2,x3,x4,x5,y1,y2,y3,y4,y5

# %%
def static_one(a1):
    a=0.5
    C=0
    N=20
    p=1
    x1=[]
    x2=[]
    x3=[]
    x4=[]
    x5=[]

    y1=[]
    y2=[]
    y3=[]
    y4=[]
    y5=[]
    gamma_list=np.arange(0,5,0.1)
    K_list=np.arange(1.,51.,1)

    x=[]
    y=[]
    for gamma in gamma_list:
        for K in K_list:
            x.append(gamma)
            y.append(K)
    for gamma,K in zip(x,y):
        s1= math.exp(1)**gamma/(math.exp(1)**gamma +  p*math.exp(0)**gamma)
        s2= math.exp(1)**gamma/(math.exp(1)**gamma +  math.exp(0)**gamma)

        u11= N/(K+1) *a + s1* N/K *a1 -C/(K+1)
        u12= s2*N/(K+1) *a +N/K *a1   -C/(K+1)
        u13= N/(K+1) *a + N/K *a1      -C/(K+1)

        u21= N/(K+2) *a + s1*N/K *a1-C/(K+2)
        u22= N/(K+2) *a + N/K *a1-C/(K+2)
        u23= s2* N/(K+2) *a + N/K *a1-C/(K+2)

        l11= (1-s1)*N/K *a1 -C/K
        l12= (1-s2)*N/(K+1) *a-C/(K+1)
        l13= N/(K+2) *a -C/(K+2)

        l21= (1-s1)* N/K *a1-C/K
        l22= N/(K+1) *a-C/(K+1)
        l23= (1-s2)*N/(K+2) *a-C/(K+2)

        A= np.array([[u11,u12,u13],[u21,u22,u23]])
        B= np.array([[l11,l12,l13],[l21,l22,l23]])
        game = nash.Game(A, B)
        eqs=game.support_enumeration()
        eqs=list(eqs)

        if len(eqs)==1:
            if [1,0]==eqs[0][0].tolist() and [0,1,0]==eqs[0][1].tolist():
                x1.append(gamma)
                y1.append(K)
            if [1,0]==eqs[0][0].tolist() and [1,0,0]==eqs[0][1].tolist():
                x2.append(gamma)
                y2.append(K)
            if [1,0]==eqs[0][0].tolist() and [0,0,1]==eqs[0][1].tolist():
                x3.append(gamma)
                y3.append(K)

        if len(eqs)>1:
            if [1,0]==eqs[0][0].tolist() and [1,0,0]==eqs[0][1].tolist():
                x4.append(gamma)
                y4.append(K)
            else:
                x5.append(gamma)
                y5.append(K)
    return x1,x2,x3,x4,x5,y1,y2,y3,y4,y5
    #plt.style.use('classic')

# %%
plt.figure(figsize=(9,27))
plt.title("Two-sided market PSNE")
plt.subplot(411)
a1=0.1
x11,x12,x13,x14,x15,y11,y12,y13,y14,y15=static_two(a1)


plt.plot(y12,x12,"o",label="(K+1,K)")
plt.plot(y11,x11,"o",label="(K+1,K+1)")
plt.plot(y15,x15,"o",label="(K+1,K+2),(K+2,K+1)")
plt.plot(y13,x13,"o",label="(K+1,K+2)")
plt.plot(y14,x14,"o",label="(K+1,K),(K+2,K+1)")

plt.xlabel('K',fontsize=18)
plt.ylabel(r'$\gamma$',fontsize=18)
title=r"$p=1$  $E(\alpha) = 0.5$" + "  " + r"$ \alpha_K=" +str(round(a1,1)) +"$"
plt.legend(loc='upper left',framealpha=1)
plt.title(title,fontsize=20)

plt.subplot(412)
a1=0.5
x11,x12,x13,x14,x15,y11,y12,y13,y14,y15=static_two(a1)

plt.plot(y12,x12,"o",label="(K+1,K)")
plt.plot(y11,x11,"o",label="(K+1,K+1)")
plt.plot(y15,x15,"o",label="(K+1,K+2),(K+2,K+1)")
plt.plot(y13,x13,"o",label="(K+1,K+2)")
plt.plot(y14,x14,"o",label="(K+1,K),(K+2,K+1)")

plt.xlabel('K',fontsize=18)
plt.ylabel(r'$\gamma$',fontsize=18)
title=r"$p=1$  $E(\alpha) = 0.5$" + "  " + r"$ \alpha_K=" +str(round(a1,1)) +"$"
plt.legend(loc='upper left',framealpha=1)
plt.title(title,fontsize=20)

plt.subplot(413)
a1=1.0
x11,x12,x13,x14,x15,y11,y12,y13,y14,y15=static_two(a1)


plt.plot(y12,x12,"o",label="(K+1,K)")
plt.plot(y11,x11,"o",label="(K+1,K+1)")
plt.plot(y15,x15,"o",label="(K+1,K+2),(K+2,K+1)")
plt.plot(y13,x13,"o",label="(K+1,K+2)")
plt.plot(y14,x14,"o",label="(K+1,K),(K+2,K+1)")

plt.xlabel('K',fontsize=18)
plt.ylabel(r'$\gamma$',fontsize=18)
title=r"$p=1$  $E(\alpha) = 0.5$" + "  " + r"$ \alpha_K=" +str(round(a1,1)) +"$"
plt.legend(loc='upper left',framealpha=1)
plt.title(title,fontsize=20)

plt.subplot(414)
a1=2.0
x11,x12,x13,x14,x15,y11,y12,y13,y14,y15=static_two(a1)


plt.plot(y12,x12,"o",label="(K+1,K)")
plt.plot(y11,x11,"o",label="(K+1,K+1)")
plt.plot(y15,x15,"o",label="(K+1,K+2),(K+2,K+1)")
plt.plot(y13,x13,"o",label="(K+1,K+2)")
plt.plot(y14,x14,"o",label="(K+1,K),(K+2,K+1)")

plt.xlabel('K',fontsize=18)
plt.ylabel(r'$\gamma$',fontsize=18)
title=r"$p=1$  $E(\alpha) = 0.5$" + "  " + r"$ \alpha_K=" +str(round(a1,1)) +"$"
plt.legend(loc='upper left',framealpha=1)
plt.title(title,fontsize=20)
# Out:
# Text(0.5,1,'$p=1$  $E(\\alpha) = 0.5$  $ \\alpha_K=2.0$')

# %%
plt.figure(figsize=(9,27))
plt.title("One-sided market PSNE")
plt.subplot(411)
a1=0.1
x11,x12,x13,x14,x15,y11,y12,y13,y14,y15=static_one(a1)


plt.plot(y12,x12,"o",label="(K+1,K)")
plt.plot(y11,x11,"o",label="(K+1,K+1)")
plt.plot(y15,x15,"o",label="(K+1,K+2),(K+2,K+1)")
plt.plot(y13,x13,"o",label="(K+1,K+2)")
plt.plot(y14,x14,"o",label="(K+1,K),(K+2,K+1)")

plt.xlabel('K',fontsize=18)
plt.ylabel(r'$\gamma$',fontsize=18)
title=r"$p=1$  $E(\alpha) = 0.5$" + "  " + r"$ \alpha_K=" +str(round(a1,1)) +"$"
plt.legend(loc='upper left',framealpha=1)
plt.title(title,fontsize=20)

plt.subplot(412)
a1=0.5
x11,x12,x13,x14,x15,y11,y12,y13,y14,y15=static_one(a1)


plt.plot(y12,x12,"o",label="(K+1,K)")
plt.plot(y11,x11,"o",label="(K+1,K+1)")
plt.plot(y15,x15,"o",label="(K+1,K+2),(K+2,K+1)")
plt.plot(y13,x13,"o",label="(K+1,K+2)")
plt.plot(y14,x14,"o",label="(K+1,K),(K+2,K+1)")

plt.xlabel('K',fontsize=18)
plt.ylabel(r'$\gamma$',fontsize=18)
title=r"$p=1$  $E(\alpha) = 0.5$" + "  " + r"$ \alpha_K=" +str(round(a1,1)) +"$"
plt.legend(loc='upper left',framealpha=1)
plt.title(title,fontsize=20)

plt.subplot(413)
a1=1.0
x11,x12,x13,x14,x15,y11,y12,y13,y14,y15=static_one(a1)


plt.plot(y12,x12,"o",label="(K+1,K)")
plt.plot(y11,x11,"o",label="(K+1,K+1)")
plt.plot(y15,x15,"o",label="(K+1,K+2),(K+2,K+1)")
plt.plot(y13,x13,"o",label="(K+1,K+2)")
plt.plot(y14,x14,"o",label="(K+1,K),(K+2,K+1)")

plt.xlabel('K',fontsize=18)
plt.ylabel(r'$\gamma$',fontsize=18)
title=r"$p=1$  $E(\alpha) = 0.5$" + "  " + r"$ \alpha_K=" +str(round(a1,1)) +"$"
plt.legend(loc='upper left',framealpha=1)
plt.title(title,fontsize=20)

plt.subplot(414)
a1=2.0
x11,x12,x13,x14,x15,y11,y12,y13,y14,y15=static_one(a1)


plt.plot(y12,x12,"o",label="(K+1,K)")
plt.plot(y11,x11,"o",label="(K+1,K+1)")
plt.plot(y15,x15,"o",label="(K+1,K+2),(K+2,K+1)")
plt.plot(y13,x13,"o",label="(K+1,K+2)")
plt.plot(y14,x14,"o",label="(K+1,K),(K+2,K+1)")

plt.xlabel('K',fontsize=18)
plt.ylabel(r'$\gamma$',fontsize=18)
title=r"$p=1$  $E(\alpha) = 0.5$" + "  " + r"$ \alpha_K=" +str(round(a1,1)) +"$"
plt.legend(loc='upper left',framealpha=1)
plt.title(title,fontsize=20)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\nashpy\algorithms\support_enumeration.py:179: RuntimeWarning:
# An even number of (2) equilibria was returned. This
# indicates that the game is degenerate. Consider using another algorithm
# to investigate.
#
#   warnings.warn(warning, RuntimeWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\nashpy\algorithms\support_enumeration.py:179: RuntimeWarning:
# An even number of (4) equilibria was returned. This
# indicates that the game is degenerate. Consider using another algorithm
# to investigate.
#
#   warnings.warn(warning, RuntimeWarning)
# Text(0.5,1,'$p=1$  $E(\\alpha) = 0.5$  $ \\alpha_K=2.0$')

# %%
for a1 in np.arange(0,2.1,0.1):  
    a=0.5
    C=0
    N=20
    p=1
    x1=[]
    x2=[]
    x3=[]
    x4=[]
  

    y1=[]
    y2=[]
    y3=[]
    y4=[]
    gamma_list=np.arange(0,5,0.1)
    K_list=np.arange(1.,51.,1)

    x=[]
    y=[]
    for gamma in gamma_list:
        for K in K_list:
            x.append(gamma)
            y.append(K)
    for gamma,K in zip(x,y):
        s1= math.exp(1)**gamma/(math.exp(1)**gamma +  p*math.exp(0)**gamma)
        s2= math.exp(1)**gamma/(math.exp(1)**gamma +  math.exp(0)**gamma)

        u11= N/(K+1) *a + s1* N/K *a1
        u12= s2*N/(K+1) *a +N/K *a1 
        u13= N/(K+1) *a + N/K *a1    

        u21= N/(K+2) *a + s1*N/K *a1
        u22= N/(K+2) *a + N/K *a1
        u23= s2* N/(K+2) *a + N/K *a1

        l11= (1-s1)*N/K *a1
        l12= (1-s2)*N/(K+1) *a
        l13= N/(K+2) *a 

        l21= (1-s1)* N/K *a1
        l22= N/(K+1) *a
        l23= (1-s2)*N/(K+2) *a

        A= np.array([[u11,u12,u13],[u21,u22,u23]])
        B= np.array([[l11,l12,l13],[l21,l22,l23]])
        game = nash.Game(A, B)
        eqs=game.support_enumeration()
        eqs=list(eqs)

        if len(eqs)==1:
            if [1,0]==eqs[0][0].tolist() and [0,1,0]==eqs[0][1].tolist():
                x1.append(gamma)
                y1.append(K)
            if [1,0]==eqs[0][0].tolist() and [1,0,0]==eqs[0][1].tolist():
                x2.append(gamma)
                y2.append(K)
            if [1,0]==eqs[0][0].tolist() and [0,0,1]==eqs[0][1].tolist():
                x3.append(gamma)
                y3.append(K)

        if len(eqs)>1:
            x4.append(gamma)
            y4.append(K)
    #plt.style.use('classic')
    plt.figure(figsize=(9,6))
    plt.axis([0, 51, -0.1, 5.])
    #,color="black")
    
    plt.plot(y2,x2,"o",label="(K+1,K)")#,color="red")
    plt.plot(y1,x1,"o",label="(K+1,K+1)")
    plt.plot(y3,x3,"o",label="(K+1,K+2)")#,color="grey")
    plt.plot(y4,x4,"o",label="(K+1,K+2),(K+2,K+1)")
    plt.xlabel('K',fontsize=18)
    plt.ylabel(r'$\gamma$',fontsize=18)
    title=r"$p=1$  $E(\alpha) = 0.5$" + "  " + r"$ \alpha_K=" +str(round(a1,1)) +"$"
    plt.legend(loc='upper left',framealpha=1)
    plt.title(title,fontsize=20)
    #name="p_"+str(round(p,1)) +"_alpha_k_0.5" +".png"
    #plt.savefig(name)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\nashpy\algorithms\support_enumeration.py:179: RuntimeWarning:
# An even number of (2) equilibria was returned. This
# indicates that the game is degenerate. Consider using another algorithm
# to investigate.
#
#   warnings.warn(warning, RuntimeWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\nashpy\algorithms\support_enumeration.py:179: RuntimeWarning:
# An even number of (4) equilibria was returned. This
# indicates that the game is degenerate. Consider using another algorithm
# to investigate.
#
#   warnings.warn(warning, RuntimeWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py:537: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
